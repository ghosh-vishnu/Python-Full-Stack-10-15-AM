# %% [markdown]
# #### Sring In Python

# %%
print("Hello Developer")
# Out:
# Hello Developer

# %%
good Morning
good Morning
good Morning
good Morning
good Morning
# Out:
#   Cell In[8], line 1
#     good Morning
#          ^
# SyntaxError: invalid syntax

# %%
print("Good Morning\n" * 10)
# Out:
# Good Morning
# Good Morning
# Good Morning
# Good Morning
# Good Morning
# Good Morning
# Good Morning
# Good Morning
# Good Morning
# Good Morning

# %%
Greeting = "good morning"
print(Greeting.capitalize())
print(Greeting.lower    ())
print(Greeting.upper())
# Out:
# Good morning
# good morning
# GOOD MORNING

# %%
text= "Developer"
print(text[::-1])
# Out:
# repoleveD

# %%
word="Hello Shubham! How Are You?"
print(word[6::])
# Out:
# Shubham! How Are You?

# %%
name,age= "Shubham", 20
print(name,age)
print(name)
print(age)
# Out:
# Shubham 20
# Shubham
# 20

# %%
a,b=20,10
print(a)
print(b)
# Out:
# 20
# 10

# %%
a=b
b=a
print(a)
print(b)
# Out:
# 10
# 10

# %%
a,b=b,a
print(a)
print(b)
# Out:
# 10
# 20

# %%
a="50"
b=100
print(type(a))
print(type(b))
# print((a)+str(b))
print(int(a)+b)# Type Casting
# Out:
# <class 'str'>
# <class 'int'>
# 150

# %%
value1=input("Enter The First Number: ")
value2=input("Enter The Second Number: ")
print("Sum of Two Numbers is :",int(value1)+int(value2))
print(type(value1))
print(type(value2))
# Out:
# Sum of Two Numver is : 160
# <class 'str'>
# <class 'str'>

# %%
# Formeting String in Python
name="Alice"
age=25
print("My Name is",name,"and i am",age,"years old")
print(f"My Name is {name} and i am {age} years old")
# Out:
# My Name is Alice and i am 25 years old
# My Name is Alice and i am 25 years old

# %%
value1= 10
value2= 20
# print(value1,"\n",value2)
print(value1,value2,sep="\n")
# Out:
# 10
# 20

# %%
first_name="Rohit"
print(first_name,end=" Sharma\n")
print(first_name," ",end="Sharma")
# Out:
# Rohit Sharma
# Rohit  Sharma

# %%
# Numerical Operations(Integer, Float, Complex)
num1= 10
num2= 20
print(num1+num2)
print(type(num1))
# Out:
# 30
# <class 'int'>

# %%
value3=45.5
print(value3)
print(type(value3))

data=True
print(type(data))

complex_num= 2j+3j
print(complex_num)
print(type(complex_num))
# Out:
# 45.5
# <class 'float'>
# <class 'bool'>
# 5j
# <class 'complex'>

# %%
complex_num1= 2+3j
complex_num2= 3+4j
sum=complex_num1+complex_num2
print(type(sum))
print(sum)
# Out:
# <class 'complex'>
# (5+7j)

# %%
# List Data Type
 # List is a Collection Data Type which is ordered and changeable(Mutable).
 # Allows duplicate members.
# List Supports Slicing and Indexing.

# %%
# Example
list=[7,8,9,10,11]

# %%
print(list)
# Out:
# [7, 8, 9, 10, 11]

# %%
print(type(list))
# Out:
# <class 'list'>

# %%
contains=["Vikash",45,"BCA","Software Developer",15400.50,True]

# %%
print(contains)
# Out:
# ['Vikash', 45, 'BCA', 'Software Developer', 15400.5, True]

# %%
print(f"My Name is {contains[0]} my salary is {contains[-2]}")
# Out:
# My Name is Vikash my salary is 15400.5

# %%
# List Methods
data=[70,80,90]
marks=75
data.append(marks)
print(data)
# Out:
# [70, 80, 90, 75]

# %%
print(data)
# Out:
# None

# %%
# Extends
classA=["Raman","Mohit","Suresh"]
classB=["Abhishek","Gopal"]
classA.extend(classB)

# %%
print(classA)
# Out:
# ['Raman', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classB
# Out:
# ['Abhishek', 'Gopal']

# %%
classB.extend(classA)

# %%
classB
# Out:
# ['Abhishek', 'Gopal', 'Raman', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classB.insert(3,"Krishna")

# %%
print(classB)
# Out:
# ['Abhishek', 'Gopal', 'Raman', 'Krishna', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classB.remove("Krishna")

# %%
classB
# Out:
# ['Abhishek', 'Gopal', 'Raman', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classB.remove("Abhishek")

# %%
classB
# Out:
# ['Gopal', 'Raman', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classB.pop(1)
# Out:
# 'Raman'

# %%
classB
# Out:
# ['Gopal', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classB.clear()

# %%
classB
# Out:
# []

# %%
a=[]
print(type(a))
# Out:
# <class 'list'>

# %%
for i in range(5):
    a.append(i)

# %%
print(a)
# Out:
# [0, 1, 2, 3, 4]

# %%
a.index(4)
# Out:
# 4

# %%
classA
classA.extend(classA)

# %%
classA.index('Abhishek')
# Out:
# 3

# %%
print(classA)
# Out:
# ['Raman', 'Mohit', 'Suresh', 'Abhishek', 'Gopal', 'Raman', 'Mohit', 'Suresh', 'Abhishek', 'Gopal']

# %%
classA.count('Abhishek')
# Out:
# 2

# %%
classA.sort()

# %%
classA
# Out:
# ['Abhishek',
#  'Abhishek',
#  'Gopal',
#  'Gopal',
#  'Mohit',
#  'Mohit',
#  'Raman',
#  'Raman',
#  'Suresh',
#  'Suresh']

# %%
classA.reverse()

# %%
classA
# Out:
# ['Suresh',
#  'Suresh',
#  'Raman',
#  'Raman',
#  'Mohit',
#  'Mohit',
#  'Gopal',
#  'Gopal',
#  'Abhishek',
#  'Abhishek']

# %%
new_list=classA.copy()

# %%
new_list
# Out:
# ['Suresh',
#  'Suresh',
#  'Raman',
#  'Raman',
#  'Mohit',
#  'Mohit',
#  'Gopal',
#  'Gopal',
#  'Abhishek',
#  'Abhishek']

# %%
# Today's Topic Cover
String--str 
        End
        Sep
        formetting String
        multiple variable declaration
        swapping  --example
        input function
        typecasting

Numerical Datatypes
        int
        float
        complex
        bool
List:
    List Methods

# %%
balance=5000
if balance>=6000:
    print("Buy Headphone")
else:
    print("Your have not sufficient balance")
# Out:
# Your have not sufficient balance

# %%
balance=4000
product_price=6000
if balance>=product_price:
    print("Buy Headphone")
else:
    print(f"Your have not sufficient balance You have to Need RS {product_price-balance} ")
# Out:
# Your have not sufficient balance You have to Need RS 2000

# %%
first_name="Kunal"
Last_Name="Kumar"
# print(first_name,Last_Name,sep="@")
# print("My first name is",first_name, "and Last name is",Last_Name)
print(f"My Name is {first_name} and last name is {Last_Name}")
# Out:
# My Name is Kunal and last name is Kumar

# %%
balance=4000
product_price=6000
if balance>=product_price:
    print("Buy Headphone")
else:
    print(f"Your have not sufficient balance You have to Need RS {product_price-balance} ")
# Out:
# Your have not sufficient balance You have to Need RS 2000

# %%
pin="8657"
balance=10000
user_pin=input("Please Enter Your PIN")
if user_pin==pin:
    print("=====================WELCOME TO SBI ATM======================")
    print("Choose Option From Below Menu")
    print("\n 1. Withdraw Money")
    print("\n 2. Check Balance")
    print("\n 3. Pin Change")
    print("\n 4. Deposit Balance")
    print("\n 5. Exit")
    choice=int(input("Choose Option (1-5) "))
    if choice==1:
        withdraw_amount=int(input("Please Enter Your Withdrawal Balance"))
        if withdraw_amount<=balance:
            if withdraw_amount%100==0:
                note500=withdraw_amount//500
                remaining=withdraw_amount%500
                note100=remaining//100
                print(f"Withdraw Successfully and Withdrawal balance is {withdraw_amount}")
                print(f"Rs 500: {note500}")
                print(f"Rs 100: {note100}")
                print()
                balance-=withdraw_amount
                print(f"Remaining Balance is {balance}")
            else:
                print("Please Enter Valid Amount")
        else:
            print("You Have Not Sufficient Balance")
    if choice==5:
        print("Thank You")
else:
    print("Invalid Password")
    print("==========THANK YOU VISIT AGAIN==================")
# Out:
# =====================WELCOME TO SBI ATM======================
# Choose Option From Below Menu
#
#  1. Withdraw Money
#
#  2. Check Balance
#
#  3. Pin Change
#
#  4. Deposit Balance
#
#  5. Exit
# Thank You

# %%
username="admin"
password='admin@123'
user=input("Enter Your User name")
passw=input('Enter Your Pass')
if user==username and passw==password:
    print("Login Suceesfully")
else:
    print("Invalid Credentials")
# Out:
# Login Suceesfully

# %%
print(5%2)
# Out:
# 1

# %%
0–100 Units  ₹5/unit
101–300  ₹7/unit
Above 300  ₹10/unit

unit=225
225-100=500
125*7=875
1375

# %%
unit=int(input("Enter Your UNIT"))
if unit<=100:
    bill=unit*5
elif unit<=200:
    bill=unit*7
else:
    bill=unit*10
print(f"Total Unit is {unit}")
print(f"TOTAL BILL IS {bill}")
# Out:
# Total Unit is 200
# TOTAL BILL IS 1400

# %%
name=input("Enter Your Name: ")
unit=int(input("Enter Your Electicity Unit: "))
customer_type=input("Enter Customer Type: ")
meter_charge=100
if unit<=100:
    bill=unit*5
elif unit<=300:
    bill=(100*5)+((unit-100)*7)
else:
    bill=(100*5)+(200*7)+((unit-300)*10)

# Enerygy Calculations

if bill>2000:
    disccount5=bill*0.05
    payble_amount=bill-disccount5

print("===============ENERGY BILL CALCULATOR=====================")
print(f"Customer Name is {name}")
print(f"Total Electicity Unit{unit}")
print(f"Customer Type {customer_type}")
print(f"Discount 5% {disccount5}")
print(f"Total Electricity Bill {bill}")
print(f"Final Payble Bill {payble_amount+meter_charge}")
# Out:
# ===============ENERGY BILL CALCULATOR=====================
# Customer Name is VISHNU
# Total Electicity Unit90
# Customer Type A
# Discount 5% 170.0
# Total Electricity Bill 450
# Final Payble Bill 3330.0

# %%
A=3400*0.05
print(A)
# Out:
# 170.0

# %%
name=input("Enter Your Name: ")
unit=int(input("Enter Your Electicity Unit: "))
customer_type=input("Enter Customer Type: ")
meter_charge=100
if unit<=100:
    bill=unit*5
elif unit<=300:
    bill=(100*5)+((unit-100)*7)
else:
    bill=(100*5)+(200*7)+((unit-300)*10)

# Enerygy Calculations

if bill>=2000:
    disccount5=bill*0.05
    payble_amount=bill-disccount5

print("===============ENERGY BILL CALCULATOR=====================")
print(f"Customer Name is {name}")
print(f"Total Electicity Unit{unit}")
print(f"Customer Type {customer_type}")
print(f"Discount 5% {disccount5}")
print(f"Total Electricity Bill {bill}")
print(f"Final Payble Bill {payble_amount+meter_charge}")
# Out:
# ===============ENERGY BILL CALCULATOR=====================
# Customer Name is Kunal
# Total Electicity Unit100
# Customer Type A
# Discount 5% 170.0
# Total Electricity Bill 500
# Final Payble Bill 3330.0

# %%
if
if-else
if-elif-else
Nested if
Multiple Conditions (and, or, not)
Comparison Operators
Membership Operators (in, not in)
Identity Operators (is, is not)
Conditional Expression (Ternary Operator)
Pass Statement
Match-Case (Python 3.10+)

# %%
age=18
if age>=20:
    print("You are Eligibal")

# %%
age=20
if age>=20:
    print("You are Eligibal")
else:
    print("You are not eligibal")
# Out:
# You are Eligibal

# %%
# if-elif-else

student_marks=int(input("Enter Your Marks"))
if student_marks>=90:
    print("Your Grade is A")
elif student_marks>=75:
    print("Your Grade is B")
elif student_marks>=60:
    print("Your Grade is C")
else:
    print("Fail")
# Out:
# Fail

# %%
# Nested IF
# An if Statement inside another if
age=38
license=False
if age>=18:
    if license:
        print("Can Drive")
    else:
        print("Required License")
else:
    print("You Are Not Eligibal")
# Out:
# Required License

# %%
Operator                Meaning                 Example
==                         equal                    a==b
!=                        NOT EQUAL                 a!=b
>                           greater than            a>b
<                            less than              a<b
>=                          greater than equal to   a>=b
<=                          less than equal to      a<=b

# %%
a=20
b=30
print(a==b)  # False
print(a!=b)  #True
print(a>b)   #False
print(a<b)  # True
print(a>=b)  # False
print(a<=b)  # True
# Out:
# False
# True
# False
# True
# False
# True

# %%
# Logical Operator
# and
# Both Condition Must Be True

age=50
citizen=False
if age>=18 and citizen:
    print("Eligibal")
else:
    print("Not Eligibal")
# Out:
# Not Eligibal

# %%
age=20
license=False
if age>=18:
    if license:
        print("Eligibal")
    else:
        print("Required License")
else:
    print("Age is Below 18")
# Out:
# Required License

# %%
age=21
license=True
if age>=18 and license:
    print("Eligibal")
else:
    print("Your Age is Below 18")
# Out:
# Eligibal

# %%
holiday=True
sunday=True
if holiday or sunday:
    print("Enjoy,No Office")
# Out:
# Enjoy,No Office

# %%
logi_in=False
 
if not logi_in:
    print("Please Login")
else:
    print("Login Successfully")
# Out:
# Please Login

# %%
age=17
license=True
if age>=18 and license:
    print("Eligibal")
elif age>=18 and not license:
    print("Required License")
else:
    print("Your Age is Below 18")
# Out:
# Your Age is Below 18

# %%
subject=["Python","Django","SQL","C++","C"]
if "C" in subject:
    print("Yes Exists")
else:
    print("No Exists")
# Out:
# Yes Exists

# %%
subject=["Python","SQL","Java"]
if "Java" not in subject:
    print("Not Available")
else:
    print("Available")
# Out:
# Available

# %%
a=[1,2]
b=[1,2,3]
if a is b:
    print("Same Object")
else:
    print("Not Same Object")
# Out:
# Not Same Object

# %%
a=[1,2]
b=[1,2,3]
if b is a:
    print("Same Object")
else:
    print("Not Same Object")
# Out:
# Not Same Object

# %%
a=[1,2]
b=[1,2]
if a is not b:
    print('Different Object')
else:
    print("Same Object")
# Out:
# Different Object

# %%
# Ternary Operator
# Short Form of IF-else
age=19
if age>=18:
    print("Adult")
else:
    print("Minor")
# Out:
# Adult

# %%
age=25
print("Adult") if age >=18 else print("Minor")
# Out:
# Adult

# %%
age=17
if age>=18:
    # print("Adult")
    pass
else:
    print("Minor")
# Out:
# Minor

# %%
day=3
if day==1:
    print("Sunday")
elif day==2:
    print("Monday")
elif day==3:
    print("Tuesday")
elif day==4:
    print("Wednesday")
else:
    print("Wrong Input")
# Out:
# Tuesday

# %%
day=6
match day:
    case 1:
        print("Sunday")
    case 2:
        print("Monday")
    case 3:
        print("Thursday")
    case 4:
        print("Wednesday")
    case 5:
        print("Friday")
    case 6:
        print("Saturday")
    case _:
        print("Invalid Input")
# Out:
# Saturday

# %%
print("=" * 50)
print("        ONLINE EXAMINATION SYSTEM")
print("=" * 50)

# ---------------- LOGIN ---------------- #
username = "student"
password = "1234"

user = input("Enter Username : ")
pwd = input("Enter Password : ")

if user == username and pwd == password:

    print("\nLogin Successful")
    print("\nChoose Subject")
    print("1. Python")
    print("2. SQL")
    print("3. Power BI")

    choice = int(input("\nEnter Choice : "))

    if choice == 1:

        questions = [
            {
                "question": "1. Which keyword is used to create a function?",
                "options": ["A. function", "B. def", "C. fun", "D. create"],
                "answer": "B"
            },

            {
                "question": "2. Which datatype is mutable?",
                "options": ["A. Tuple", "B. String", "C. List", "D. Integer"],
                "answer": "C"
            },

            {
                "question": "3. Which loop is used for fixed iterations?",
                "options": ["A. while", "B. for", "C. do while", "D. switch"],
                "answer": "B"
            },

            {
                "question": "4. Which operator checks equality?",
                "options": ["A. =", "B. ==", "C. !=", "D. >"],
                "answer": "B"
            },

            {
                "question": "5. Which function takes input from user?",
                "options": ["A. print()", "B. input()", "C. len()", "D. int()"],
                "answer": "B"
            }
        ]

    elif choice == 2:

        questions = [
            {
                "question": "1. Which keyword is used to retrieve data?",
                "options": ["A. GET", "B. SELECT", "C. SHOW", "D. DISPLAY"],
                "answer": "B"
            },

            {
                "question": "2. Which clause filters records?",
                "options": ["A. WHERE", "B. ORDER", "C. GROUP", "D. LIMIT"],
                "answer": "A"
            },

            {
                "question": "3. Which command inserts data?",
                "options": ["A. INSERT", "B. UPDATE", "C. DELETE", "D. CREATE"],
                "answer": "A"
            },

            {
                "question": "4. Which keyword sorts records?",
                "options": ["A. SORT", "B. ORDER BY", "C. GROUP BY", "D. HAVING"],
                "answer": "B"
            },

            {
                "question": "5. SQL stands for?",
                "options": ["A. Structured Query Language",
                            "B. Simple Query Language",
                            "C. Standard Query List",
                            "D. System Query Language"],
                "answer": "A"
            }
        ]

    elif choice == 3:

        questions = [
            {
                "question": "1. Which software is used for dashboards?",
                "options": ["A. Excel", "B. Power BI", "C. Word", "D. VS Code"],
                "answer": "B"
            },

            {
                "question": "2. Which language is used in Power BI?",
                "options": ["A. Java", "B. Python", "C. DAX", "D. HTML"],
                "answer": "C"
            },

            {
                "question": "3. Which view is used to create visuals?",
                "options": ["A. Report", "B. Model", "C. Data", "D. Home"],
                "answer": "A"
            },

            {
                "question": "4. Which chart compares values?",
                "options": ["A. Bar Chart", "B. Card", "C. Table", "D. Map"],
                "answer": "A"
            },

            {
                "question": "5. Power BI is developed by?",
                "options": ["A. Google", "B. Microsoft", "C. Apple", "D. IBM"],
                "answer": "B"
            }
        ]

    else:
        print("Invalid Choice")
        exit()


    score=0
    print("==============EXAM START===========================")
    for q in questions:
        print(q['question'])
        for option in q['options']:
            print(option)
        user_answer=input("Enter Your Answer A B C D").upper()
        if user_answer== q['answer']:
            # print("Correct Answer")
            score+=1
        else:
            print("Wrong Answer")
            print(f"The Correct Answer is {q['answer']}")
    print(f"Your Question is {len(questions)}")
    print(f'Total Score is {score}')
    print(f"Wrong Answer is{len(questions)-score}")
    print(f"Final Score {score}/{len(questions)}")
    percentage=(score/len(questions)*100)
    print(f"Percentage:{percentage}")

    if percentage>=80:
        print("Your Grade is A")
        print("Excellent")
    elif percentage>=60:
        print("Your Grade is B")
        print("Very Good")
    elif percentage>=45:
        print("Your Grade is C")
        print("Good")
    else:
        print("Fail")
        print("Need Practice")
else:
    print("Please Enter Correct Credentials")
# Out:
# ...
#         ONLINE EXAMINATION SYSTEM
# ...
#
# Login Successful
#
# Choose Subject
# 1. Python
# 2. SQL
# 3. Power BI
# ==============EXAM START===========================
# 1. Which software is used for dashboards?
# A. Excel
# B. Power BI
# C. Word
# D. VS Code
# 2. Which language is used in Power BI?
# A. Java
# B. Python
# C. DAX
# D. HTML
# Wrong Answer
# The Correct Answer is C
# 3. Which view is used to create visuals?
# A. Report
# B. Model
# C. Data
# D. Home
# 4. Which chart compares values?
# A. Bar Chart
# B. Card
# C. Table
# D. Map
# 5. Power BI is developed by?
# A. Google
# B. Microsoft
# C. Apple
# D. IBM
# Your Question is 5
# Total Score is 4
# Wrong Answer is1
# Final Score 4/5
# Percentage:80.0
# Your Grade is A
# Excellent

# %%
3
0 0
0 1
0 2
1 0
1 1
1 2
2 0
2 1
2 2
# Out:
#   Cell In[4], line 2
#     0 0
#       ^
# SyntaxError: invalid syntax

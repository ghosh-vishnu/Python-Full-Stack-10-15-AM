# %%
What is Dictionay?
A dictionart is a mutable(changeable),unordered and insertion-ordered collection data type.
it store data in ket-value pairs
dict literal is {} seprated by :
# Out:
#   Cell In[4], line 2
#     A dictionart is a mutable(changeable),unordered and insertion-ordered collection data type.
#       ^
# SyntaxError: invalid syntax

# %%
student={
    'name':"Vishnu",
    'age':25,
    'course':'python'
}

# %%
print(student)
# Out:
# {'name': 'Vishnu', 'age': 25, 'course': 'python'}

# %%
print(type(student))
# Out:
# <class 'dict'>

# %%
data=dict(name='Rahul',age=22)
print(data)
# Out:
# {'name': 'Rahul', 'age': 22}

# %%
data1=dict([('name','Mohit'),('age',22)])
print(data1)
# Out:
# {'name': 'Mohit', 'age': 22}

# %%
# Rules:
1. Keys must be unique
2. values can be duplicated.
3. keys should be immutable.
4. Dict is mutable

# %%
data={
    'name':'vishnu',
    'age':25,
    'age':30
}

# %%
print(data)
# Out:
# {'name': 'vishnu', 'age': 30}

# %%
# Allow  Key Types
data={
    1:'One',
    2.5:'Float',
    True:'Boolean',
    (1,2):'Tuple',
    [3,4]:'List'
}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Allow  Key Types
# ----> 2 data={
#       3     1:'One',
#       4     2.5:'Float',
#       5     True:'Boolean',
#       6     (1,2):'Tuple',
#       7     [3,4]:'List'
#       8 }
#
# TypeError: unhashable type: 'list'

# %%
# Accessing Values in dictionary
student
# Out:
# {'name': 'Vishnu', 'age': 25, 'course': 'python'}

# %%
print(student['course3'],student['name'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 print(student['course3'],student['name'])
#
# KeyError: 'course3'

# %%
print(student.get('course',"Not Found"))
# Out:
# python

# %%
# Updating Dictionary
student
# Out:
# {'name': 'Vishnu', 'age': 25, 'course': 'python'}

# %%
student['age']=30
print(student)
# Out:
# {'name': 'Vishnu', 'age': 30, 'course': 'python'}

# %%
# Adding New Key in Existing Distionary
student['Fee']=8000
print(student)
# Out:
# {'name': 'Vishnu', 'age': 30, 'course': 'python', 'Fee': 8000}

# %%
# Deleteing Elements
del student['Fee']

# %%
student
# Out:
# {'name': 'Vishnu', 'age': 30, 'course': 'python'}

# %%
# pop()
student.pop('age')
# Out:
# 30

# %%
student
# Out:
# {'name': 'Vishnu', 'course': 'python'}

# %%
student['city']='Noida'

# %%
student
# Out:
# {'name': 'Vishnu', 'course': 'python', 'city': 'Noida'}

# %%
student.popitem()
# Out:
# ('city', 'Noida')

# %%
student.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 student.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
student.clear()

# %%
student
# Out:
# {}

# %%
data
# Out:
# {1: 'Boolean', 2.5: 'Float', (1, 2): 'Tuple'}

# %%
data.keys()
# Out:
# dict_keys([1, 2.5, (1, 2)])

# %%
data.values()
# Out:
# dict_values(['Boolean', 'Float', 'Tuple'])

# %%
data.items()
# Out:
# dict_items([(1, 'Boolean'), (2.5, 'Float'), ((1, 2), 'Tuple')])

# %%
data
# Out:
# {1: 'Boolean', 2.5: 'Float', (1, 2): 'Tuple'}

# %%
data.update({
    1:'int',
    'city':'Kolkata'
})

# %%
data
# Out:
# {1: 'int', 2.5: 'Float', (1, 2): 'Tuple', 'city': 'Kolkata'}

# %%
new_dict=data.copy()

# %%
print(new_dict)
# Out:
# {1: 'int', 2.5: 'Float', (1, 2): 'Tuple', 'city': 'Kolkata'}

# %%
# Membership Operator(in)
print('address' in data)
print('address' not in data)
# Out:
# False
# True

# %%
len(data)
# Out:
# 4

# %%
# Nested Dictionary
student={
    'BCA':{
       'name':'Rahul',
       'age':21
    },
    'B.Tech':{
        'name':"Mohit",
        'age':26
    }
}

# %%
student
# Out:
# {'BCA': {'name': 'Rahul', 'age': 21}, 'B.Tech': {'name': 'Mohit', 'age': 26}}

# %%
print(student['B.Tech'])
# Out:
# {'name': 'Mohit', 'age': 26}

# %%
students=[
    {'name':"Vishnu",'age':25,'city':'Noida'},
    {'name':"Rahul",'age':28,'city':'JSR'},
    {'name':"Rohit",'age':30,'city':'Delhi'},

]

# %%
students
# Out:
# [{'name': 'Vishnu', 'age': 25, 'city': 'Noida'},
#  {'name': 'Rahul', 'age': 28, 'city': 'JSR'},
#  {'name': 'Rohit', 'age': 30, 'city': 'Delhi'}]

# %%
print(students[1]['name'],students[1]['age'])
# Out:
# Rahul 28

# %%
# List Inside Dictioanry
result={
    'name':'Rahul',
    'marks':[87,96,74,65,89]
}

# %%
print(result)
# Out:
# {'name': 'Rahul', 'marks': [87, 96, 74, 65, 89]}

# %%
print(result['name'],result['marks'][-2])
# Out:
# Rahul 65

# %%
for i in result:
    print(i)
# Out:
# name
# marks

# %%
name  Rahul
marks  []

# %%
for i in result.items():
    print(i)
# Out:
# ('name', 'Rahul')
# ('marks', [87, 96, 74, 65, 89])

# %%
for i in result.items():
    print(i)
# Out:
# ('name', 'Rahul')
# ('marks', [87, 96, 74, 65, 89])

# %%
for i,j in result.items():
    print(i,j)
# Out:
# name Rahul
# marks [87, 96, 74, 65, 89]

# %%
result.items()
# Out:
# dict_items([('name', 'Rahul'), ('marks', [87, 96, 74, 65, 89])])

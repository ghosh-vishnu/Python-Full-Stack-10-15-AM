# %%
Characteristics of Set.
> Unordered(No Indexing)

>Mutable(Can Add/Remove Elements)

>Unique Value Store(No Duplicates Allow)

> Cannot store List Disctionary ,set
# Out:
#   Cell In[1], line 1
#     Characteristics of Set.
#                     ^
# SyntaxError: invalid syntax

# %%
# Createing Set

a=set()
print(type(a))
# Out:
# <class 'set'>

# %%
b={34,34,1,2,34}
print(type(b))
# Out:
# <class 'set'>

# %%
print(b)
# Out:
# {1, 34, 2}

# %%
data={
    34,56.8,True,3+1j
}

# %%
data
# Out:
# {(3+1j), 34, 56.8, True}

# %%
data=['A','A','B','B','C','C']
print(data)
converted_set=set(data)
print(converted_set)
# Out:
# ['A', 'A', 'B', 'B', 'C', 'C']
# {'C', 'B', 'A'}

# %%
converted_set
# Out:
# {'A', 'B', 'C'}

# %%
converted_set[1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 converted_set[1]
#
# TypeError: 'set' object is not subscriptable

# %%
for i in converted_set:
    print(i)
# Out:
# C
# B
# A

# %%
# Membership Operator
data={45,20,48}
print(20 in data)
# Out:
# True

# %%
print(100 in data)
# Out:
# False

# %%
len(data)
# Out:
# 3

# %%
data
# Out:
# {20, 45, 48}

# %%
a=100
data.add(a)

# %%
data
# Out:
# {20, 45, 48, 100}

# %%
d=[8,9,6,6,8]
print(set(d))

data.update(d)
# Out:
# {8, 9, 6}

# %%
data
# Out:
# {6, 8, 9, 20, 45, 48, 100}

# %%
# Remove()

data
# Out:
# {6, 8, 9, 20, 45, 48, 100}

# %%
data.remove(20)
data
# Out:
# {6, 8, 9, 45, 48, 100}

# %%
data.remove(200)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 data.remove(200)
#
# KeyError: 200

# %%
data.discard(200)

# %%
data.discard(100)

# %%
data
# Out:
# {6, 8, 9, 45, 48}

# %%
data
# Out:
# {6, 8, 9, 45, 48}

# %%
print(data.pop())
data
# Out:
# 9
# {45, 48}

# %%
data
# Out:
# {9, 45, 48}

# %%
data=[8056,89,78,54,45,18,96]
print(set(data))
# Out:
# {96, 45, 78, 18, 54, 8056, 89}

# %%
data=[8056,89,78,54,45,18,96]
print(set(data))

# %%
da={2,9,10,7,45,66,88,8}
d=[2,7,8,10]
for i in d:
    da.discard(i)
print(da)
# Out:
# {66, 9, 45, 88}

# %%
my_data=[2,99,10,7,45,88,66,88]
data=set(my_data)

# %%
result=data & {9,8}
print(result)
# Out:
# set()

# %%
data
# Out:
# {2, 7, 10, 45, 66, 88, 99}

# %%
my_data=[2,99,10,7,45,8,66,]
remain=[i for i in my_data if i in [88,66]]
print(set(remain))
# Out:
# {66}

# %%
my_data=set(my_data)

# %%
my_data.discard()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[69], line 1
# ----> 1 my_data.discard(remain)
#
# TypeError: cannot use 'list' as a set element (unhashable type: 'list')

# %%
da={2,9,10,7,45,66,88,8}
d=[2,7,8,10]
for i in d:
    da.discard(i)
print(da)
# Out:
# {66, 9, 45, 88}

# %%
A={3,5,9}
B={10,17,18}

# %%
print(A.union(B))
# Out:
# {17, 18, 3, 5, 9, 10}

# %%
print(A|B)
# Out:
# {17, 18, 3, 5, 9, 10}

# %%
A={3,5,9}
B={8,9,18}
print(A.intersection(B))
# Out:
# {9}

# %%
print(A & B)
# Out:
# {9}

# %%
A={3,5,9}
B={8,9,18}
print(B.difference(A))
# Out:
# {8, 18}

# %%
print(A-B)
# Out:
# {3, 5}

# %%
A={3,5,9}
B={8,9,18}
print(B.symmetric_difference(A))
# Out:
# {3, 5, 8, 18}

# %%
print(A^B)
# Out:
# {3, 5, 8, 18}

# %%
A={8,7}
B={8,9,18}
print(A.issubset(B))
# Out:
# False

# %%
A={8,7,9}
B={8,9}

print(A.issuperset(B))
# Out:
# True

# %%
A={1,2}
B={3,4}
print(A.isdisjoint(B))
# Out:
# True

# %%
A={4,2,7}
B={8,5,6}
print(A.isdisjoint(B))
# Out:
# True

# %%
data
# Out:
# {2, 7, 10, 45, 66, 88, 99}

# %%
data=frozenset(data)

# %%
data.add(500)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 data.add(500)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
data
# Out:
# frozenset({2, 7, 10, 45, 66, 88, 99})

# %%
data=set(data)

# %%
data
# Out:
# {2, 7, 10, 45, 66, 88, 99}

# %%
square={i * i for i in data}
print(square)
# Out:
# {7744, 4, 4356, 100, 9801, 2025, 49}

# %%
data={{1,2,3},{4,5,6}} # Nested Set Not Allowed
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 data={{1,2,3},{4,5,6}}
#
# TypeError: cannot use 'set' as a set element (unhashable type: 'set')

# %%
data={frozenset({1,2,3}),frozenset({4,5,6})}

# %%
data=set(data)

# %%
data
# Out:
# {frozenset({1, 2, 3}), frozenset({4, 5, 6})}
